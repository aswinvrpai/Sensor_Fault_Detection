# %%
import csv
import os
from dotenv import load_dotenv
import sys
load_dotenv()
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Work_Directory\Learn\DS_Projects\Sensor_Fault_Detection\artifacts\raw.csv')

# %%
df.head(10)
# Out:
#                         _id  Sensor-1  Sensor-2   Sensor-3   Sensor-4  \
# 0  66c84f838110b1626700e98a   2968.33   2476.58  2216.7333  1748.0885
# 1  66c84f838110b1626700e98b   2961.04   2506.43  2170.0666  1364.5157
# 2  66c84f838110b1626700e98c   3072.03   2500.68  2205.7445  1363.1048
# 3  66c84f838110b1626700e98d   3021.83   2419.83  2205.7445  1363.1048
# 4  66c84f838110b1626700e98e   3006.95   2435.34  2189.8111  1084.6502
# 5  66c84f838110b1626700e98f   3003.72   2537.66  2210.7778  2008.9216
# 6  66c84f838110b1626700e990   2953.59   2504.86  2224.6778  1308.6479
# 7  66c84f838110b1626700e991   3086.52   2360.04  2204.2333  2110.8288
# 8  66c84f838110b1626700e992   3048.76   2545.68  2224.6778  1308.6479
# 9  66c84f838110b1626700e993   2984.06   2619.60  2225.0222  1730.8480
#
#    Sensor-5  Sensor-6  Sensor-7  Sensor-8  Sensor-9  ...  Sensor-581  \
# 0    1.1127     100.0   97.5822    0.1242    1.5300  ...         NaN
# ...

# %%
df.isna().sum()
# Out:
# _id           0
# Sensor-1      1
# Sensor-2      0
# Sensor-3      3
# Sensor-4      3
#              ..
# Sensor-586    0
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Length: 591, dtype: int64
